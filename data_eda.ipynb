# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('datasets/salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                           Job Title      Salary Estimate  \
# 0                    Data Scientist  $135,000 /yr (est.)
# 1            Data Quality Scientist  $112,729 /yr (est.)
# 2         Senior Data Scientist x 2  $146,990 /yr (est.)
# 3                    Data Scientist  $125,000 /yr (est.)
# 4  Earth Observation Data Scientist   $94,842 /yr (est.)
#
#                                      Job Description  Rating  \
# 0  Overview\nOur client is seeking experienced Da...    -1.0
# 1  SYNOPSIS:\nData Quality Scientist\n\n\nApplica...     4.3
# 2  Organisation/Entity: Transport For NSW\nJob Ca...     3.7
# 3  Job description\nData Scientist Skills\nProgra...    -1.0
# 4  SYNOPSIS:\nEarth Observation Data Scientist\n\...     4.3
#
#                              Company Name  Location                   Size  \
# 0                         Interpro People    Sydney                     -1
# 1               Geoscience Australia\n4.3  Canberra  501 to 1000 Employees
# ...

# %%
df.describe()
# Out:
#            Rating      Founded      hourly         salary         age  \
# count  847.000000   847.000000  847.000000     847.000000  847.000000
# mean     3.005549   562.067296    0.190083  103077.547580   14.218418
# std      1.875607   891.024411    0.392598   29985.950584   30.908593
# min     -1.000000    -1.000000    0.000000   28870.000000   -1.000000
# 25%      3.600000    -1.000000    0.000000   90000.000000   -1.000000
# 50%      3.800000    -1.000000    0.000000   91479.000000   -1.000000
# 75%      3.900000  1905.000000    0.000000  109421.000000   21.000000
# max      5.000000  2015.000000    1.000000  234000.000000  117.000000
#
#         python_yn      aws_yn    excel_yn  communication_yn     desc_len
# count  847.000000  847.000000  847.000000        847.000000   847.000000
# mean     0.014168    0.009445    0.075561          0.070838  1117.403778
# std      0.118252    0.096783    0.264450          0.256706   943.135866
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'salary', 'company_txt',
#        'age', 'python_yn', 'aws_yn', 'excel_yn', 'communication_yn',
#        'job_title', 'seniority', 'desc_len'],
#       dtype='object')

# %%
# Histograms

columns = ['Rating', 'Founded', 'hourly', 'salary', 'age', 'python_yn', 'aws_yn', 'excel_yn', 'communication_yn', 'desc_len']

fig, axs = plt.subplots(len(columns), figsize=(8, 40))
fig.subplots_adjust(hspace=0.3)
for n, col in enumerate(columns):
    sns.histplot(df, x=col, ax=axs[n])

# %%
df.salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['salary'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['age'])
# Out:
# <AxesSubplot:>

# %%
df[['age', 'salary', 'Rating']].corr()
# Out:
#              age    salary    Rating
# age     1.000000 -0.161996  0.230738
# salary -0.161996  1.000000 -0.111978
# Rating  0.230738 -0.111978  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','salary','Rating','desc_len']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'salary', 'company_txt',
#        'age', 'python_yn', 'aws_yn', 'excel_yn', 'communication_yn',
#        'job_title', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Size', 'Type of ownership',
       'Industry', 'Sector', 'Revenue', 'company_txt', 
             'python_yn', 'aws_yn', 'excel_yn', 'communication_yn', 'job_title', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    plt.subplots(figsize=(20,5))
    print(f"Graph for {i}: total = {len(cat_num)}")
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: total = 15
# Graph for Size: total = 9
# Graph for Type of ownership: total = 7
# Graph for Industry: total = 8
# Graph for Sector: total = 8
# Graph for Revenue: total = 7
# Graph for company_txt: total = 42
# Graph for python_yn: total = 2
# Graph for aws_yn: total = 2
# Graph for excel_yn: total = 2
# Graph for communication_yn: total = 2
# Graph for job_title: total = 6
# Graph for seniority: total = 3

# %%
pd.pivot_table(df, index = 'job_title', values='salary')
# Out:
#                                salary
# job_title
# analyst                 105629.617391
# analytics                89713.357143
# data engineer            90000.000000
# data quality scientist  112729.000000
# data scientist          123039.076923
# mle                      68426.866667

# %%
pd.pivot_table(df, index=['job_title', 'seniority'], values='salary')
# Out:
#                                          salary
# job_title              seniority
# analyst                jr          93600.000000
#                        na         105963.258552
# analytics              na          89713.357143
# data engineer          na          90000.000000
# data quality scientist na         112729.000000
# data scientist         na         114846.000000
#                        senior     145277.428571
# mle                    na          68426.866667

# %%
pd.pivot_table(df, index='Location', values='salary').sort_values('salary', ascending=False)
# Out:
#                         salary
# Location
# Australia        234000.000000
# Alexandria       147248.000000
# New South Wales  124275.047619
# Bankstown        117791.000000
# Sydney           112572.165060
# Brisbane         112011.000000
# Canberra         110653.705882
# St Leonards      109421.000000
# Wollongong        91479.000000
# Melbourne         90428.684211
# South Australia   90234.000000
# Perth             90000.000000
# Adelaide          85936.142857
# Nowra             79335.000000
# Belconnen         71024.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'salary', 'company_txt',
#        'age', 'python_yn', 'aws_yn', 'excel_yn', 'communication_yn',
#        'job_title', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'python_yn', 'aws_yn', 
                'excel_yn', 'communication_yn', 'Type of ownership', 'salary', 'job_title']]

# %%
for i in df_pivots.columns:
    if i != 'salary':
        print(i)
        print('')
        print(pd.pivot_table(df_pivots, index=i, values='salary').sort_values(i, ascending = False))
        print('-'*80)
    else:
        pass
# Out:
# Rating
#
#                salary
# Rating
#  5.0    197600.000000
#  4.8     66000.000000
#  4.4     90234.000000
#  4.3    104673.285714
#  4.2     96200.542373
#  4.0     84143.103448
#  3.9     81982.035714
#  3.8     94107.532710
#  3.7    123016.300000
#  3.6    140687.630252
#  3.3    195000.000000
#  3.0    100260.000000
# -1.0    109417.625333
# --------------------------------------------------------------------------------
# Industry
#
#                                                 salary
# Industry
# National Services & Agencies             103610.583333
# Investment & Asset Management             71024.000000
# Information Technology Support Services  182584.615385
# HR Consulting                            135029.894737
# Colleges & Universities                   87707.927536
# Business Consulting                      165001.000000
# Advertising & Public Relations            80000.000000
# -1                                       100118.743195
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values='salary', aggfunc = 'count')
# Out:
# python_yn                             0    1
# Revenue
# $1 to $2 billion (USD)              2.0  NaN
# $1 to $5 million (USD)             26.0  NaN
# $10+ billion (USD)                 21.0  NaN
# $100 to $500 million (USD)        123.0  1.0
# $500 million to $1 billion (USD)   65.0  2.0
# -1                                 81.0  NaN
# Unknown / Non-Applicable          517.0  9.0

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'salary', 'company_txt',
#        'age', 'python_yn', 'aws_yn', 'excel_yn', 'communication_yn',
#        'job_title', 'seniority', 'desc_len'],
#       dtype='object')

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
