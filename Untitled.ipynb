# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                           Job Title      Salary Estimate  \
# 0                    Data Scientist  $135,000 /yr (est.)
# 1            Data Quality Scientist  $112,729 /yr (est.)
# 2         Senior Data Scientist x 2  $146,990 /yr (est.)
# 3                    Data Scientist  $125,000 /yr (est.)
# 4  Earth Observation Data Scientist   $94,842 /yr (est.)
#
#                                      Job Description  Rating  \
# 0  Overview\nOur client is seeking experienced Da...    -1.0
# 1  SYNOPSIS:\nData Quality Scientist\n\n\nApplica...     4.3
# 2  Organisation/Entity: Transport For NSW\nJob Ca...     3.7
# 3  Job description\nData Scientist Skills\nProgra...    -1.0
# 4  SYNOPSIS:\nEarth Observation Data Scientist\n\...     4.3
#
#                              Company Name  Location                   Size  \
# 0                         Interpro People    Sydney                     -1
# 1               Geoscience Australia\n4.3  Canberra  501 to 1000 Employees
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'salary', 'company_txt',
#        'age', 'python_yn', 'spark_yn', 'aws_yn', 'excel_yn',
#        'communication_yn'],
#       dtype='object')
